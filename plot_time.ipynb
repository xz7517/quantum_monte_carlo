# %%
import matplotlib.pyplot as plt
import numpy as np

thread = [1, 2, 4, 8, 16, 32]
time = [22744, 12255, 7450, 4121, 3275,4353]

plt.plot(thread, time,'x', label = 'N=100')
plt.xlabel('number of threads')
plt.ylabel('real time(ms)')
plt.legend()
plt.show()

# %%
fig, ax =plt.subplots(1,1)
data=[[-244.076, -738.938, -1334.93, -2143.93],
      [-244.076, -739.833, -1344.95, -2145.52],
      [-243.651, -738.918, -1340.49, -2145.52],
      [-244.076, -739.833, -1344.95, -2145.52],
      [-244.076, -739.833, -1344.95, -2145.52]]
column_labels=["N= 50", "N = 100", "N= 150" , "N=200"]
row_labels = ["continuous_ave", "continuous_best", "discrete_ave", "discrete_best", "Amplify"]
ax.axis('tight')
ax.axis('off')
ax.table(cellText=data, rowLabels = row_labels,colLabels=column_labels,loc="center")

plt.show()
